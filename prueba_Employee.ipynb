# %% [markdown]
# # 📊 Análisis de Datos sobre [Employee_Attrition]
# **Autor:** Kevin Tupac Agüero
# **Fecha:** 22 de febrero de 2025
# **Descripción:** Breve resumen del propósito del cuaderno.
# **Fuente de Datos:** [CSV_Employee_Attrition](https://www.kaggle.com/datasets/itssuru/hr-employee-attrition)
# **Tecnologías Usadas:** Python, Pandas, Matplotlib, Scikit-learn.
# ---
# ## 📌 Contenido del Cuaderno
# - Carga de los datos
#   - Informacion de cada columna
#   - Revisar valores faltantes
#   - Revisar balance de la data
#   - Estandarizar los datos
# - EDA
#   - Analizas variables y relaciones
# - Visualizacion
#   - Visualizar relaciones
# - Procesar Data
#   - Dividir datos
#   - Eliminacion de datos
#   - Remover datos
#   - Estructurar la data
#   - Balancera dataset
# - Seleccion de Caracteristicas
#   - Revisar la relacion entre variables
# - Entrenar el modelo
#   - Divir dataset en train y test
#   - Estandarizar datos
#   - Construir modelo
#   - Metodos de optimizacion
# - Seleccionar el mejor modelo
# - Construir la API
#
# ## Diccionario del dataset:
#
# | Variable                   | Tipo de Dato  | Tipo de Variable | Descripción |
# |----------------------------|---------------|------------------|-------------|
# | PerformanceRating          | Numérico      | Ordinal         | Evaluación del desempeño del empleado |
# | RelationshipSatisfaction   | Numérico      | Ordinal         | Satisfacción con las relaciones en el trabajo |
# | StockOptionLevel           | Numérico      | Ordinal         | Nivel de opciones sobre acciones otorgadas |
# | EnvironmentSatisfaction    | Numérico      | Ordinal         | Satisfacción con el ambiente laboral |
# | WorkLifeBalance            | Numérico      | Ordinal         | Equilibrio entre trabajo y vida personal |
# | JobInvolvement             | Numérico      | Ordinal         | Nivel de compromiso con el trabajo |
# | JobLevel                   | Numérico      | Ordinal         | Nivel del puesto dentro de la empresa |
# | JobSatisfaction            | Numérico      | Ordinal         | Satisfacción con el puesto de trabajo |
# | Education                  | Numérico      | Ordinal         | Nivel educativo alcanzado |
# | Age                        | Numérico      | Discreto        | Edad del empleado |
# | DailyRate                  | Numérico      | Discreto        | Pago diario del empleado |
# | MonthlyIncome              | Numérico      | Discreto        | Ingreso mensual del empleado |
# | MonthlyRate                | Numérico      | Discreto        | Tarifa mensual asignada al empleado |
# | NumCompaniesWorked         | Numérico      | Discreto        | Número de empresas en las que ha trabajado |
# | PercentSalaryHike          | Numérico      | Discreto        | Porcentaje de aumento salarial |
# | TotalWorkingYears          | Numérico      | Discreto        | Total de años trabajados |
# | TrainingTimesLastYear      | Numérico      | Discreto        | Número de entrenamientos recibidos el último año |
# | YearsAtCompany             | Numérico      | Discreto        | Años trabajando en la empresa actual |
# | YearsInCurrentRole         | Numérico      | Discreto        | Años en su puesto actual |
# | YearsSinceLastPromotion    | Numérico      | Discreto        | Años desde su última promoción |
# | YearsWithCurrManager       | Numérico      | Discreto        | Años con su actual gerente |
# | DistanceFromHome           | Numérico      | Discreto        | Distancia entre el hogar y el trabajo (en km) |
# | EmployeeNumber             | Numérico      | Discreto        | Identificador único del empleado |
# | HourlyRate                 | Numérico      | Discreto        | Tarifa por hora del empleado |
# | BusinessTravel             | Categórico    | Nominal         | Frecuencia de viajes por trabajo |
# | EducationField             | Categórico    | Nominal         | Área de estudio del empleado |
# | MaritalStatus              | Categórico    | Nominal         | Estado civil del empleado |
# | OverTime                   | Categórico    | Nominal         | Indica si trabaja horas extras |
# | Department                 | Categórico    | Nominal         | Departamento en el que trabaja |
# | JobRole                    | Categórico    | Nominal         | Rol o cargo del empleado |
# | Gender                     | Categórico    | Nominal         | Género del empleado |
# | Attrition                  | Categórico    | Nominal         | Indica si el empleado ha dejado la empresa |

# %% [markdown]
# ## Cargar Datos

# %%
#Cargar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Suppress the FutureWarning
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#Opciones
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("HR-Employee-Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
data.Age.hist()
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
data.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
data.Attrition.value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
data.Attrition.value_counts()/len(data)*100
# Out:
# Attrition
# No     83.877551
# Yes    16.122449
# Name: count, dtype: float64

# %% [markdown]
# **Informacion del Dataset**
# 1. Cuenta con 1470 filas y 35 columnas.
# 2. El dataset cuenta con 2 tipos de datos: int y object.
# 3. No hay datos faltantes.
# 4. El target es la columna Attriction.
# 5. Esta desvalanceado: 16% (yes) - 84% (no)

# %%
data['Attrition'] = np.where(data['Attrition']=='Yes',1,0)

# %%
data = data.drop(['EmployeeNumber'],axis=1)

# %%
conteo_valores = data['Attrition'].value_counts()
data['Attrition'].value_counts(0)
# Out:
# Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64

# %% [markdown]
# ### Revisar balance de la data

# %%
plt.figure(figsize=(8,4))
sns.barplot(x=conteo_valores.index, y=conteo_valores.values)
plt.title('Distribución de las clases')
plt.xlabel('Clases')
plt.ylabel('Frecuencia')

# Añadir los porcentajes en las barras
for i, valor in enumerate(conteo_valores.values):
    plt.text(i, valor + 100, f'{valor}', ha='center', va='bottom')

plt.show()

# %%
data_num = data.select_dtypes(include=['int'])

# %%
data_num
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41          1       1102                 1          2              1
# 1      49          0        279                 8          1              1
# 2      37          1       1373                 2          2              1
# 3      33          0       1392                 3          4              1
# 4      27          0        591                 2          1              1
# ...   ...        ...        ...               ...        ...            ...
# 1465   36          0        884                23          2              1
# 1466   39          0        613                 6          1              1
# 1467   27          0        155                 4          3              1
# 1468   49          0       1023                 2          3              1
# 1469   34          0        628                 8          3              1
#
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Exporacion de datos numericos

# %%
def plot_int_distributions(dataframe, columns_per_row=3, color='steelblue'):
    """
    Genera histogramas con KDE para visualizar la distribución de columnas enteras.

    Parámetros:
        dataframe (pd.DataFrame): DataFrame con los datos a visualizar.
        columns_per_row (int): Número de gráficos por fila. Default: 3.
        color (str): Color de los gráficos. Default: 'lightseagreen'.
    """
    # Filtrar solo columnas de tipo entero
    data_int = dataframe.select_dtypes(include=['int64'])

    if data_int.empty:
        print("No hay columnas de tipo entero en el DataFrame.")
        return

    # Calcular el número de filas dinámicamente
    num_cols = len(data_int.columns)
    rows = -(-num_cols // columns_per_row)  # División redondeada hacia arriba

    # Configurar la figura
    fig, axes = plt.subplots(rows, columns_per_row, figsize=(5 * columns_per_row, 3 * rows))
    axes = axes.flatten()  # Convertir en lista para facilitar el acceso

    # Graficar distribuciones con histplot (reemplazo de distplot)
    for idx, col in enumerate(data_int.columns):
        sns.histplot(data=data_int[col], kde=True, ax=axes[idx], color=color)
        axes[idx].set_title(f"Distribución de {col}", fontsize=12, fontweight='bold')
        axes[idx].set_xlabel("Valor", fontsize=10)
        axes[idx].set_ylabel("Frecuencia", fontsize=10)
        axes[idx].grid(True, linestyle='--', alpha=0.5)

    # Ocultar ejes vacíos si hay menos columnas que espacios en la cuadrícula
    for i in range(idx + 1, len(axes)):
        fig.delaxes(axes[i])

    plt.tight_layout()
    plt.show()

# Llamar a la función con el DataFrame
plot_int_distributions(data_num)

# %% [markdown]
# ### Exporacion de datos categoricos

# %%
# Seleccionar características categóricas con valores únicos entre 2 y 9
cata = [col for col in data.drop(columns=['Attrition']).columns if 1 < data[col].nunique() < 10]

# Graficar
for col in cata:
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # Gráfico de barras de la relación entre categoría y 'Attrition'
    sns.barplot(x=col, y='Attrition', data=data, ax=axes[0], color='steelblue')
    axes[0].set_title(f"Relación de {col} con Attrition")

    # Conteo de cada categoría
    sns.countplot(x=col, data=data, ax=axes[1], palette="pastel")
    axes[1].set_title(f"Frecuencia de {col}")

    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear el jointplot con scatter y colores por 'Attrition'
g = sns.jointplot(
    data=data, x="Age", y="MonthlyIncome", hue="Attrition", palette="coolwarm", kind="scatter"
)

# Mejorar la visualización de los puntos
for ax in g.ax_joint.collections:
    ax.set_edgecolor("black")  # Borde en los puntos para mejor contraste
    ax.set_alpha(0.75)  # Ajustar la transparencia para evitar saturación visual

# Ajustar título y etiquetas
g.figure.suptitle("Relación entre Edad y Salario Mensual", fontsize=14, fontweight="bold")
g.set_axis_labels("Edad", "Salario Mensual", fontsize=12)

plt.tight_layout()  # Ajusta automáticamente el diseño
plt.show()

# %%
data.groupby(['Attrition'])['Age'].mean().to_frame()
# Out:
#                  Age
# Attrition
# 0          37.561233
# 1          33.607595

# %%
data.groupby(['Attrition'])['MonthlyIncome'].mean().to_frame()
# Out:
#            MonthlyIncome
# Attrition
# 0            6832.739659
# 1            4787.092827

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 7))


plt.figure(figsize=(15,7))
sns.swarmplot( x="Department", y='MonthlyIncome', data = data ,hue='Attrition', palette="coolwarm")
# Ajustes visuales
plt.xticks(rotation=45)  # Rotar etiquetas del eje X si hay muchas categorías
plt.title("Distribución de Ingresos Mensuales por Departamento", fontsize=14, fontweight="bold")
plt.xlabel("Departamento")
plt.ylabel("Salario Mensual")
plt.legend(title="Attrition")

plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
data.groupby('Department')['Attrition'].mean().to_frame()
# Out:
#                         Attrition
# Department
# Human Resources          0.190476
# Research & Development   0.138398
# Sales                    0.206278

# %%
data.groupby(['Department','Attrition'])['MonthlyIncome'].mean().to_frame()
# Out:
#                                   MonthlyIncome
# Department             Attrition
# Human Resources        0            7345.980392
#                        1            3715.750000
# Research & Development 0            6630.326087
#                        1            4108.075188
# Sales                  0            7232.240113
#                        1            5908.456522

# %%
#Columnas que solo tienen un unico valor, son innecesarias para este estudio
data.drop(columns=['EmployeeCount'], inplace=True)
data.drop(columns=['Over18'], inplace=True)
data.drop(columns=['StandardHours'], inplace=True)

# %%
X = data.drop(['Attrition'],axis=1)
y = data[['Attrition']]

# %%
# Calcular número de valores únicos por columna
feature_val_count = X.nunique().to_frame(name='unique_values')

# %%
# Filtrar columnas con más de un valor único
X = X[feature_val_count[feature_val_count['unique_values'] > 1].index]

# %%
# Separar datos numéricos y categóricos
num = X.select_dtypes(include=['number'])
char = X.select_dtypes(include=['object'])

# %%
# Filtrar variables categóricas (≤20 valores únicos) y numéricas (>20 valores únicos)
cat_data = num.loc[:, num.nunique() <= 20]
num_data = num.loc[:, num.nunique() > 20]

# %%
# Combinar datos categóricos
categorical_data = pd.concat([char, cat_data], axis=1)

# %%
categorical_data
# Out:
#          BusinessTravel              Department EducationField  Gender  \
# 0         Travel_Rarely                   Sales  Life Sciences  Female
# 1     Travel_Frequently  Research & Development  Life Sciences    Male
# 2         Travel_Rarely  Research & Development          Other    Male
# 3     Travel_Frequently  Research & Development  Life Sciences  Female
# 4         Travel_Rarely  Research & Development        Medical    Male
# ...                 ...                     ...            ...     ...
# 1465  Travel_Frequently  Research & Development        Medical    Male
# 1466      Travel_Rarely  Research & Development        Medical    Male
# 1467      Travel_Rarely  Research & Development  Life Sciences    Male
# 1468  Travel_Frequently                   Sales        Medical    Male
# 1469      Travel_Rarely  Research & Development        Medical    Male
#
#                         JobRole MaritalStatus OverTime  Education  \
# ...

# %%
# Mostrar resultados
print("Datos Numéricos:", num_data.columns.tolist())
print("Datos Categóricos:", categorical_data.columns.tolist())
# Out:
# Datos Numéricos: ['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'TotalWorkingYears', 'YearsAtCompany']
# Datos Categóricos: ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime', 'Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
num_data.describe(percentiles=[0.01,0.05,0.10,0.25,0.50,0.75,0.85,0.9,0.99])
# Out:
#                Age    DailyRate  DistanceFromHome   HourlyRate  MonthlyIncome  \
# count  1470.000000  1470.000000       1470.000000  1470.000000    1470.000000
# mean     36.923810   802.485714          9.192517    65.891156    6502.931293
# std       9.135373   403.509100          8.106864    20.329428    4707.956783
# min      18.000000   102.000000          1.000000    30.000000    1009.000000
# 1%       19.000000   117.000000          1.000000    30.000000    1382.460000
# 5%       24.000000   165.350000          1.000000    33.000000    2097.900000
# 10%      26.000000   242.800000          1.000000    38.000000    2317.600000
# 25%      30.000000   465.000000          2.000000    48.000000    2911.000000
# 50%      36.000000   802.000000          7.000000    66.000000    4919.000000
# 75%      43.000000  1157.000000         14.000000    83.750000    8379.000000
# 85%      47.000000  1297.000000         20.000000    90.000000   10927.800000
# ...

# %%
numerical = num_data.apply(lambda x: x.clip(lower=x.quantile(0.01), upper=x.quantile(0.99)))

# %%
numerical.describe(percentiles=[0.01,0.05,0.10,0.25,0.50,0.75,0.85,0.9,0.99])
# Out:
#                Age    DailyRate  DistanceFromHome   HourlyRate  MonthlyIncome  \
# count  1470.000000  1470.000000       1470.000000  1470.000000    1470.000000
# mean     36.918810   802.482993          9.192517    65.891156    6503.407177
# std       9.099146   403.260237          8.106864    20.329428    4700.530849
# min      19.000000   117.000000          1.000000    30.000000    1382.460000
# 1%       19.000000   117.000000          1.000000    30.000000    1389.732600
# 5%       24.000000   165.350000          1.000000    33.000000    2097.900000
# 10%      26.000000   242.800000          1.000000    38.000000    2317.600000
# 25%      30.000000   465.000000          2.000000    48.000000    2911.000000
# 50%      36.000000   802.000000          7.000000    66.000000    4919.000000
# 75%      43.000000  1157.000000         14.000000    83.750000    8379.000000
# 85%      47.000000  1297.000000         20.000000    90.000000   10927.800000
# ...

# %% [markdown]
# ## Relacion de caracteristicas

# %%
plt.figure(figsize=(12, 8))
sns.set_theme(style="white")

# Calcular la matriz de correlación
correlation_matrix = numerical.corr()

# Crear el mapa de calor con una paleta de colores más amigable
sns.heatmap(correlation_matrix,
            annot=True,
            fmt=".2f",
            cmap="coolwarm",
            center=0,
            linewidths=1,
            square=True,
            mask=np.triu(correlation_matrix),  # Oculta la mitad superior para mejor lectura
            cbar_kws={"shrink": 0.75},
            annot_kws={"size": 9})

# Agregar título
plt.title("Matriz de Correlación de Variables Numéricas", fontsize=14, fontweight='bold')
plt.show()

# %%
# Función para eliminar características altamente correlacionadas
def remove_correlated_features(data, threshold=0.75):
    correlation_matrix = data.corr()
    correlated_features = set()

    for col in correlation_matrix.columns:
        for row in correlation_matrix.index:
            if col != row and abs(correlation_matrix.loc[col, row]) > threshold:
                correlated_features.add(col)

    return correlated_features

# %%
# Identificar y eliminar características con correlación mayor a 0.75
correlated_features = remove_correlated_features(numerical, 0.75)
numerical.drop(columns=correlated_features, inplace=True)

# %%
# Mostrar las columnas eliminadas
print(f"Se eliminaron {len(correlated_features)} características correlacionadas:", correlated_features)
# Out:
# Se eliminaron 2 características correlacionadas: {'MonthlyIncome', 'TotalWorkingYears'}

# %% [markdown]
# ## Reduccion de caracteristicas

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
# Eliminar columnas innecesarias
categorical_data.drop(columns=['Gender', 'PerformanceRating'], inplace=True)

# %%
# Convertir a tipo categórico
catagorical = categorical_data.astype(str)

# %%
# Crear variables dummy (one-hot encoding) excluyendo la primera categoría para evitar multicolinealidad
catag_dum = pd.get_dummies(catagorical, drop_first=True)

# %%
# Seleccionar las 20 mejores características categóricas usando Chi-cuadrado
selector = SelectKBest(chi2, k=10)
X_selected = selector.fit_transform(catag_dum, y)

# %%
selector
trans_chi2 = selector.fit_transform(catag_dum, y)
chi2_scores = selector.scores_
chi2_pvalues = selector.pvalues_

# %%
results_df = pd.DataFrame({
    "Features (Chi2)": catag_dum.columns,
    "Scores (Chi2)": chi2_scores,
    "p-values (Chi2)": chi2_pvalues
})

# %%
results_df.sort_values(by="Scores (Chi2)", ascending=False).head(10)
# Out:
#                      Features (Chi2)  Scores (Chi2)  p-values (Chi2)
# 19                      OverTime_Yes      63.845067     1.345990e-15
# 16      JobRole_Sales Representative      34.290268     4.747499e-09
# 18              MaritalStatus_Single      30.771669     2.902446e-08
# 63                StockOptionLevel_1      19.940896     7.987336e-06
# 30                        JobLevel_2      16.096623     6.019126e-05
# 0   BusinessTravel_Travel_Frequently      15.816623     6.978671e-05
# 10     JobRole_Laboratory Technician      11.699495     6.251707e-04
# 13         JobRole_Research Director      10.978010     9.219939e-04
# 32                        JobLevel_4      10.196599     1.406999e-03
# 11                   JobRole_Manager       9.496136     2.059051e-03

# %%
# Obtener nombres de las columnas seleccionadas
selected_columns = catag_dum.columns[selector.get_support()]
X_ca = pd.DataFrame(X_selected, columns=selected_columns, index=catag_dum.index)

# %%
# Unir características numéricas y categóricas seleccionadas
X_all = pd.concat([numerical, X_ca], axis=1)

# %%
X_all.shape
# Out:
# (1470, 16)

# %% [markdown]
# ## Balanceo de dataset

# %%
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Aplicar sobremuestreo para equilibrar la clase minoritaria
ros = RandomOverSampler(sampling_strategy='minority', random_state=1)
X_resampled, Y_resampled = ros.fit_resample(X_all, y)

# %%
X_resampled.iloc[1].values
# Out:
# array([49.0, 279, 8, 61, 24907.0, 10, True, False, False, False, False,
#        False, False, True, False, True], dtype=object)

# %% [markdown]
# ## Entrenamiento de Modelo

# %%
# Dividir los datos en conjunto de entrenamiento y prueba (80%-20%)
X_train, X_test, y_train, y_test = train_test_split(X_resampled, Y_resampled, test_size=0.2, random_state=1)

# %%
X_train.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyRate',
#        'YearsAtCompany', 'BusinessTravel_Travel_Frequently',
#        'JobRole_Laboratory Technician', 'JobRole_Manager',
#        'JobRole_Research Director', 'JobRole_Sales Representative',
#        'MaritalStatus_Single', 'OverTime_Yes', 'JobLevel_2', 'JobLevel_4',
#        'StockOptionLevel_1'],
#       dtype='object')

# %%
# Mostrar dimensiones y tasas de atrición
print(f"Shape del conjunto de entrenamiento: {X_train.shape}")
print(f"Shape del conjunto de prueba: {X_test.shape}")
print(f"Tasa de Atrición en entrenamiento: {y_train.mean()}")
print(f"Tasa de Atrición en prueba: {y_test.mean()}")
# Out:
# Shape del conjunto de entrenamiento: (1972, 16)
# Shape del conjunto de prueba: (494, 16)
# Tasa de Atrición en entrenamiento: Attrition    0.494929
# dtype: float64
# Tasa de Atrición en prueba: Attrition    0.520243
# dtype: float64

# %% [markdown]
# ### Estandarizacion de Data

# %%
# Estandarizar las características numéricas
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = pd.DataFrame(X_train, columns=X_all.columns)
X_test = pd.DataFrame(X_test, columns=X_all.columns)

# %%
X_train.iloc[6].values
# Out:
# array([ 0.88623937,  0.36113355, -0.83631479,  1.17039584,  0.04023115,
#        -0.56189189, -0.53983431,  1.99179678, -0.22990515, -0.19745483,
#        -0.29715353, -0.79102551, -0.78764077, -0.66923148, -0.23714965,
#        -0.73200106])

# %%
y_train = y_train.to_numpy().ravel()
y_test = y_test.to_numpy().ravel()

# %%
y_train
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %% [markdown]
# ## Seleccion de Modelos

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, ConfusionMatrixDisplay
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
# Función para entrenar y evaluar el modelo
def model_eval(X_train, y_train, X_test, y_test, model):
    model.fit(X_train, y_train)

    # Predicciones en entrenamiento y prueba
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Evaluación en conjunto de entrenamiento
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_precision = precision_score(y_train, y_train_pred)
    train_recall = recall_score(y_train, y_train_pred)

    print("Evaluación en Entrenamiento:")
    print(f'Accuracy: {train_accuracy:.2f}, Precision: {train_precision:.2f}, Recall: {train_recall:.2f}')
    print("=" * 40)

    # Evaluación en conjunto de prueba
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_precision = precision_score(y_test, y_test_pred)
    test_recall = recall_score(y_test, y_test_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    print("Evaluación en Prueba:")
    print(f'Accuracy: {test_accuracy:.2f}, Precision: {test_precision:.2f}, Recall: {test_recall:.2f}, F1 Score: {test_f1:.2f}')
    print("=" * 40)

    # Matriz de confusión
    ConfusionMatrixDisplay.from_estimator(model, X_test, y_test, cmap='Blues')

    # Reporte de clasificación
    print("\nReporte de Clasificación:")
    print(classification_report(y_test, y_test_pred))

# %% [markdown]
# ### Modelo: Arbol de decisión

# %%
# Entrenamiento con un Árbol de Decisión
model_dt = DecisionTreeClassifier(random_state=11, max_depth=10, criterion="gini")
print("Modelo: Árbol de Decisión")
model_eval(X_train, y_train, X_test, y_test, model_dt)
# Out:
# Modelo: Árbol de Decisión
# Evaluación en Entrenamiento:
# Accuracy: 0.95, Precision: 0.94, Recall: 0.97
# ...
# Evaluación en Prueba:
# Accuracy: 0.87, Precision: 0.85, Recall: 0.90, F1 Score: 0.88
# ...
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86       237
#            1       0.85      0.90      0.88       257
#
#     accuracy                           0.87       494
#    macro avg       0.87      0.87      0.87       494
# weighted avg       0.87      0.87      0.87       494

# %% [markdown]
# ### Optimizacion por Hiperparametros y GridSearchCV

# %%
# Configurar el modelo base
dt_model = DecisionTreeClassifier(random_state=3)

# %%
# Definir el espacio de búsqueda para los hiperparámetros
param_grid = {
    'max_depth': [7, 8, 9],
    'min_samples_split': [9, 11, 15],
    'min_samples_leaf': [9, 11, 13],
    'criterion': ['gini']
}

# %%
# Iniciar la búsqueda de hiperparámetros con GridSearchCV
grid_search = GridSearchCV(estimator=dt_model, param_grid=param_grid, cv=10, n_jobs=-3)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(random_state=3), n_jobs=-3,
#              param_grid={'criterion': ['gini'], 'max_depth': [7, 8, 9],
#                          'min_samples_leaf': [9, 11, 13],
#                          'min_samples_split': [9, 11, 15]})

# %%
# Mostrar los mejores hiperparámetros encontrados
best_params = grid_search.best_params_
print("Mejores Hiperparámetros Encontrados:")
print(best_params)
# Out:
# Mejores Hiperparámetros Encontrados:
# {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 9, 'min_samples_split': 9}

# %%
# Crear un modelo con los mejores hiperparámetros
dt_best = DecisionTreeClassifier(
    criterion=best_params['criterion'],
    max_depth=best_params['max_depth'],
    min_samples_leaf=best_params['min_samples_leaf'],
    min_samples_split=best_params['min_samples_split'],
    random_state=3
)

# %%
print("\nEvaluación del Árbol de Decisión con Hiperparámetros Óptimos:")
model_eval(X_train, y_train, X_test, y_test, dt_best)
# Out:
# Evaluación del Árbol de Decisión con Hiperparámetros Óptimos:
# Evaluación en Entrenamiento:
# Accuracy: 0.88, Precision: 0.87, Recall: 0.89
# ...
# Evaluación en Prueba:
# Accuracy: 0.79, Precision: 0.79, Recall: 0.80, F1 Score: 0.80
# ...
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.78       237
#            1       0.79      0.80      0.80       257
#
#     accuracy                           0.79       494
#    macro avg       0.79      0.79      0.79       494
# weighted avg       0.79      0.79      0.79       494

# %% [markdown]
# ### Modelo: K-Neighbors

# %%
# Lista para almacenar la suma de los errores cuadráticos (SSE)
sse = []

# Probamos valores de K entre 1 y 10
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42)
    kmeans.fit(X_train)
    sse.append(kmeans.inertia_)  # Inercia: suma de las distancias al centroide

# %%
# Gráfico del método del codo
plt.figure(figsize=(10, 5))
plt.plot(range(1, 11), sse, marker='o', linestyle='dashed', color='seagreen')
plt.xlabel('Número de Clusters (K)')
plt.ylabel('Suma de los Errores Cuadráticos (SSE)')
plt.title('Método del Codo para K-Means')
plt.show()

# %%
classifier = KNeighborsClassifier(n_neighbors=5)
print("Model Name : KNeighborsClassifier:")
model_eval(X_train, y_train, X_test, y_test, classifier)
# Out:
# Model Name : KNeighborsClassifier:
# Evaluación en Entrenamiento:
# Accuracy: 0.87, Precision: 0.81, Recall: 0.97
# ...
# Evaluación en Prueba:
# Accuracy: 0.81, Precision: 0.77, Recall: 0.90, F1 Score: 0.83
# ...
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.87      0.71      0.78       237
#            1       0.77      0.90      0.83       257
#
#     accuracy                           0.81       494
#    macro avg       0.82      0.81      0.81       494
# weighted avg       0.82      0.81      0.81       494

# %% [markdown]
# ### Modelo: Random Forest

# %%
rf = RandomForestClassifier(n_estimators=50, random_state=1, max_depth=6)
print("Model Name : Random Forest")
model_eval(X_train, y_train, X_test, y_test, rf)
# Out:
# Model Name : Random Forest
# Evaluación en Entrenamiento:
# Accuracy: 0.86, Precision: 0.88, Recall: 0.82
# ...
# Evaluación en Prueba:
# Accuracy: 0.82, Precision: 0.85, Recall: 0.78, F1 Score: 0.82
# ...
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82       237
#            1       0.85      0.78      0.82       257
#
#     accuracy                           0.82       494
#    macro avg       0.82      0.82      0.82       494
# weighted avg       0.82      0.82      0.82       494

# %% [markdown]
# ### Modelo: Random Forest Con Hiperparametros

# %%
# Definir el modelo base
fit_rf = RandomForestClassifier(random_state=1)

# %%
# Definir los hiperparámetros para la búsqueda
param_dist = {
    'max_depth': [7, 8, 9],
    'max_features': ['sqrt'],  # Cambié 'auto' por 'sqrt'
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [8, 9, 11, 12],
    'min_samples_leaf': [8, 9, 11, 13]
}

# %%
# Configurar GridSearchCV
cv_rf = GridSearchCV(fit_rf, param_grid=param_dist, cv=10, n_jobs=3)

# %%
# Ajustar el modelo con los datos
cv_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(random_state=1), n_jobs=3,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [7, 8, 9], 'max_features': ['sqrt'],
#                          'min_samples_leaf': [8, 9, 11, 13],
#                          'min_samples_split': [8, 9, 11, 12]})

# %%
# Obtener los mejores hiperparámetros
print('Best Parameters using grid search: \n', cv_rf.best_params_)
# Out:
# Best Parameters using grid search:
#  {'criterion': 'entropy', 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8}

# %%
# Aplicar los mejores hiperparámetros al modelo
fit_rf.set_params(
    n_estimators=200,
    bootstrap=True,
    criterion=cv_rf.best_params_['criterion'],
    max_features='sqrt',
    max_depth=cv_rf.best_params_['max_depth'],
    min_samples_leaf=cv_rf.best_params_['min_samples_leaf'],
    min_samples_split=cv_rf.best_params_['min_samples_split']
)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=9, min_samples_leaf=8,
#                        min_samples_split=8, n_estimators=200, random_state=1)

# %%
# Evaluar el modelo optimizado
print("Model Name: Random Forest with Hyperparameter Optimization")
model_eval(X_train, y_train, X_test, y_test, fit_rf)
# Out:
# Model Name: Random Forest with Hyperparameter Optimization
# Evaluación en Entrenamiento:
# Accuracy: 0.92, Precision: 0.92, Recall: 0.92
# ...
# Evaluación en Prueba:
# Accuracy: 0.86, Precision: 0.89, Recall: 0.84, F1 Score: 0.86
# ...
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       237
#            1       0.89      0.84      0.86       257
#
#     accuracy                           0.86       494
#    macro avg       0.86      0.86      0.86       494
# weighted avg       0.86      0.86      0.86       494

# %% [markdown]
# ### Modelo: Soporte Vector Machine

# %%
svc_model = SVC(kernel='rbf', gamma='scale')
print("Model Name : SVC")
model_eval(X_train, y_train, X_test, y_test, svc_model)
# Out:
# Model Name : SVC
# Evaluación en Entrenamiento:
# Accuracy: 0.85, Precision: 0.83, Recall: 0.86
# ...
# Evaluación en Prueba:
# Accuracy: 0.83, Precision: 0.83, Recall: 0.84, F1 Score: 0.84
# ...
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       237
#            1       0.83      0.84      0.84       257
#
#     accuracy                           0.83       494
#    macro avg       0.83      0.83      0.83       494
# weighted avg       0.83      0.83      0.83       494

# %%
model = SVC()

# %%
model.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
param_grid = {'C': [0.01,0.1,1, 10, 100, 1000],
              'gamma': [1,0.1,0.01,0.001,0.0001],
              'kernel': ['rbf']}

# %%
cv_svc = GridSearchCV(SVC(probability=True),param_grid,refit=True,verbose = 3)

# %%
cv_svc.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END .......C=0.01, gamma=1, kernel=rbf;, score=0.504 total time=   1.0s
# [CV 2/5] END .......C=0.01, gamma=1, kernel=rbf;, score=0.506 total time=   1.0s
# [CV 3/5] END .......C=0.01, gamma=1, kernel=rbf;, score=0.505 total time=   0.9s
# [CV 4/5] END .......C=0.01, gamma=1, kernel=rbf;, score=0.505 total time=   0.6s
# [CV 5/5] END .......C=0.01, gamma=1, kernel=rbf;, score=0.505 total time=   0.6s
# [CV 1/5] END .....C=0.01, gamma=0.1, kernel=rbf;, score=0.504 total time=   0.6s
# [CV 2/5] END .....C=0.01, gamma=0.1, kernel=rbf;, score=0.506 total time=   0.6s
# [CV 3/5] END .....C=0.01, gamma=0.1, kernel=rbf;, score=0.505 total time=   0.6s
# [CV 4/5] END .....C=0.01, gamma=0.1, kernel=rbf;, score=0.505 total time=   0.6s
# [CV 5/5] END .....C=0.01, gamma=0.1, kernel=rbf;, score=0.505 total time=   0.6s
# [CV 1/5] END ....C=0.01, gamma=0.01, kernel=rbf;, score=0.504 total time=   0.6s
# ...

# %%
# Obtener los mejores hiperparámetros
print('Best Parameters using grid search: \n', cv_svc.best_params_)
# Out:
# Best Parameters using grid search:
#  {'C': 10, 'gamma': 1, 'kernel': 'rbf'}

# %%
best_MVS_model= cv_svc.best_estimator_

# %%
best_MVS_model
# Out:
# SVC(C=10, gamma=1, probability=True)

# %%
print("Model Name: SVC with Hyperparameter Optimization")
model_eval(X_train, y_train, X_test, y_test, best_MVS_model)
# Out:
# Model Name: SVC with Hyperparameter Optimization
# Evaluación en Entrenamiento:
# Accuracy: 1.00, Precision: 1.00, Recall: 1.00
# ...
# Evaluación en Prueba:
# Accuracy: 0.97, Precision: 1.00, Recall: 0.95, F1 Score: 0.97
# ...
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       237
#            1       1.00      0.95      0.97       257
#
#     accuracy                           0.97       494
#    macro avg       0.97      0.97      0.97       494
# weighted avg       0.97      0.97      0.97       494

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(best_MVS_model, X_train, y_train, cv=5)
print("Accuracy promedio en validación cruzada:", scores.mean())
# Out:
# Accuracy promedio en validación cruzada: 0.9685561909657523

# %%
from sklearn.model_selection import learning_curve
import numpy as np
import matplotlib.pyplot as plt

train_sizes, train_scores, test_scores = learning_curve(best_MVS_model, X_train, y_train, cv=5)
train_mean = np.mean(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)

plt.plot(train_sizes, train_mean, 'o-', label="Training Score")
plt.plot(train_sizes, test_mean, 'o-', label="Cross-validation Score")
plt.legend()
plt.xlabel("Training Size")
plt.ylabel("Score")
plt.title("Learning Curve")
plt.show()

# %% [markdown]
# #a

# %%
import joblib

# Guardar el modelo entrenado
joblib.dump(best_MVS_model, "modelo_svc.pkl")
# Out:
# ['modelo_svc.pkl']

# %%
# 1. Cargar el modelo SVC guardado
with open("modelo_svc.pkl", "rb") as f:
    modelo = joblib.load(f)
# Out:
# <class 'sklearn.svm._classes.SVC'>

# %%
numericas = np.array([[5.1, 3.5, 1.4, 0.2]])
categoricas = np.array([[1, 0]])

# %%
# 4. Aplicar la transformación SOLO a las columnas numéricas
numericas_escaladas = scaler.transform(numericas)

# %%
# 5. Concatenar nuevamente los datos numéricos escalados con los categóricos sin escalar
nuevo_dato_escalado = np.hstack((numericas_escaladas, categoricas))

# %%
# 6. Realizar la predicción
prediccion = modelo.predict(nuevo_dato_escalado)
